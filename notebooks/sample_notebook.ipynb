# %% [markdown]
# # Sample Jupyter Notebook
#
# This is a sample notebook to demonstrate the basic structure of a Jupyter notebook.

# %% [markdown]
# ## Introduction
#
# Welcome to your first Jupyter notebook! This notebook will help you get started with Python programming.

# %%
# Example: Print a greeting
print("Hello, World!")

# %%
# Example: Basic arithmetic
a = 5
b = 3
print(f"{a} + {b} = {a + b}")
print(f"{a} - {b} = {a - b}")
print(f"{a} * {b} = {a * b}")
print(f"{a} / {b} = {a / b}")

# %% [markdown]
# ## Next Steps
#
# Feel free to add more cells and experiment with Python code!
